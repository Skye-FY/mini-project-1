# %%
# Import libraries
import re
import numpy as np
import random

# %%
# Define global variables
single_deck = {
    'Spades':{
        'Ace':[1,11],
        'Two':2,
        'Three':3,
        'Four':4,
        'Five':5,
        'Six':6,
        'Seven':7,
        'Eight':8,
        'Nine':9,
        'Ten':10,
        'Jack':10,
        'Queen':10,
        'King':10
    },
    'Hearts':{
        'Ace':[1,11],
        'Two':2,
        'Three':3,
        'Four':4,
        'Five':5,
        'Six':6,
        'Seven':7,
        'Eight':8,
        'Nine':9,
        'Ten':10,
        'Jack':10,
        'Queen':10,
        'King':10
    },
    'Clubs':{
        'Ace':[1,11],
        'Two':2,
        'Three':3,
        'Four':4,
        'Five':5,
        'Six':6,
        'Seven':7,
        'Eight':8,
        'Nine':9,
        'Ten':10,
        'Jack':10,
        'Queen':10,
        'King':10
    },
    'Diamonds':{
        'Ace':[1,11],
        'Two':2,
        'Three':3,
        'Four':4,
        'Five':5,
        'Six':6,
        'Seven':7,
        'Eight':8,
        'Nine':9,
        'Ten':10,
        'Jack':10,
        'Queen':10,
        'King':10
    },
}

#game goal
game_goal = 21
#initial check amount
init_check = 0
#check options
#minimum $5 for check values at 5 at once
#maximum $500 for check values at 500 at once
check_op = [5, 25, 50, 100, 500]
#number of games played
game_times = 0
#player's cards at hand 
p_hands = []
#player total facevalue at hand
p_facevalue = 0
#dealer's cards at hand
d_hands = []
#dealer total facevalue at hand
d_facevalue = 0
#iterator
itr = lambda x: [i for i in x]
#{'Spades Ace': [1, 11]}

# %%
# Define functions

def checkBank(checks_chosen):

    
def dealerDrawsCard(deck):
a = random.choice(list(single_deck.items()))
a
b = random.choice(list(a[1].items()))
b
bb = lambda x: [i for i in x]
c = [a[0],bb(b)]
c
d = [c[0],c[1][0],c[1][1]]
d
card_drawn = dict()
card_drawn[' '.join(d[:2])] = d[2]
card_drawn

#def FacevalueComputer(on_hand):

#def compareHands(dealer, player):

#def
# Out:
#   File "<ipython-input-61-4319017c0796>", line 28
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
def checkBank(current_bal):
    if game_times == 0:
        print('Your current check amount is %d.' % current_bal)
        print('Checks are available in below values.',check_op,'\nHow much checks in value do you want to exchange?')
        
        
        flag1=False
        while flag1==False:
            check_add = int(input('Please choose your desired recharge value.' ))
            if check_add not in check_op:
                print('ERROR: Please enter valid check value.')
            else:
                init_check += check_add
                flag1=True
        return print(input('Your current check amount is %d.\nDo you want to make a bet?\nIf so, how much?' % init_check))

checkBank(init_check)
